# %% [markdown]
# <a href="https://colab.research.google.com/github/Han-Xu-qu/cisc121/blob/main/Assignement_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CISC 121 – Assignment-1
#
# ## 🔗 Problem
# Fizz Buzz – https://leetcode.com/problems/fizz-buzz/
#
# Palindrome Number – https://leetcode.com/problems/palindrome-number/
#
# Reverse Integer – https://leetcode.com/problems/reverse-integer/
#
# Two Sum – https://leetcode.com/problems/two-sum/
#
# Valid Palindrome – https://leetcode.com/problems/valid-palindrome/

# %% [markdown]
# #  Problem 1

# %% [markdown]
# ## 1. Understanding & Breakdown
#
# _Understand the problem, inputs/outputs, constraints, and  write down your plan or steps to solve the problem or draw the flowchart using digital or real pen-paper. Insert the image._
#
# **AI Level 1** is allowed to understand the concept, but you need to sketch the problem down by yourself.
#
# **Your effort is more important than the accuracy for this section**

# %% [markdown]
# Problem: when given an integar n, find the range of numbers 1 to n, then create an array in which every number that is divisible by 3 is replaced by a string "Fizz", every number divisible by 5 is replaced by the string "Buzz", every number thats divisible by both is replaced by the string "FizzBuzz" and numbers that are not divisible by either/both are replaced with the string version of itself
#
# i.e:
# 1. create range of nums (1,n)
# 2. for every number in the range, check if divisble by both 3 & 5
#   if yes, append "FizzBuzz" to the array, go to next number
#   if not, continue to 3
# 3. check if num is divisible by 3
#   if yes, append "Fizz" to array, go to next number
#   if not, continue
# 4. check if num is divisible by 5
#   if yes, append "Buzz" to array, go to next number
#   if not, continue
# 5. append the string of the number to the array
# 6. go to next number

# %% [markdown]
# ## 2. Peer Review & Draft Code
#
# **Review Guidance:**
# Visit the **"Solutions"** tab on LeetCode for the selected problem and review at least one top-rated solution. You may also search for relevant discussions or Q&A threads on **Stack Overflow** or other forums to understand how others approached the problem.
#
# Then, write your own version based on what you understood. The goal is not to copy but to apply what you learned. Always include links to the resources you reviewed.
#
# ---
#
# ### **Example Answer (for "Palindrome Number"):**
#
# I reviewed the top solution under the LeetCode “Solutions” tab and one post on Stack Overflow:
# https://stackoverflow.com/questions/17129222/how-to-check-if-a-number-is-palindrome-in-python
#
# I learned that I can reverse the integer using a loop with modulo and division instead of converting it to a string. Using this idea, I tried writing a function that reverses the number and compares it to the original.

# %%
from typing_extensions import final
# Your draft code here (does not need to be fully correct)
'''peer review: I reviewed the top solution on LeetCode for FizzBuzz
https://leetcode.com/problems/fizz-buzz/solutions/6646296/conquer-fizzbuzz-with-the-cleanest-one-liner-logic-ever/
Using this solution, i learnt that i can use modulo to determine the divisibility of an integar n. with this in mind,
i wrote the code'''
def FIZZBUZZ(n: int) -> list:
  final_prod = []
  for num in range(1,n + 1): # creates a range of numbers from 1 to n

    if num % 3 == 0 and num % 5 == 0: #checks if divisible by both 3 and 5
      final_prod.append( "FizzBuzz")
    elif num % 3 == 0: # checks if divisible by 3
      final_prod.append("Fizz")
    elif num % 3 == 0: #checks if divisible by 5
      final_prod.append("buzz")
    else: # since all previous conditions were not met, last possible output
      final_prod.append(str(num))
    return final_prod

# %% [markdown]
# ## 3. Final Correct Code
#
# _This version must pass all required test cases and handle edge cases correctly._
#
# At this stage, you may:
# - Use reviewed solutions or programming AI tools (e.g., ChatGPT, GitHub Copilot) to refine and fix errors.
# - Refactor your draft to ensure accuracy and completeness.
#
#  **AI Level 4 is allowed**, but you **must include a disclaimer** that clearly states what tools you used, how you used them, and for which part of the code.

# %%
# Final working solution
# [AI Disclaimer example: Used ChatGPT with prompt “How to handle recursion base case” only for concept]
def fizzbuzz(integar: int) -> list:
  output = []
  start = 1
  integar = int(integar) #makes sure that the input is an integar
  if integar < 0: # checks if input is less than 0
    start = integar # reverses the range so it includes negative nums
    integar = 1
  for num in range (start, integar + 1):
    if num % 3 == 0 and num % 5 == 0:
      output.append("FizzBuzz")
    elif num % 3 == 0:
      output.append("Fizz")
    elif num % 5 == 0:
      output.append("Buzz")
    else:
      output.append(str(num))
  return output

# %% [markdown]
# Add the screenshot of output for all the test cases from your working solutions. ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 4. Review & Fixes
# _What did you improve from your draft? 2 fixes with your comments._

# %%
# Fix 1: added section to deal with negative integar inputs aswell as float/non integar inputs
integar = int(integar) #makes sure that the input is an integar
  if integar < 0: # checks if input is less than 0
    start = integar # reverses the range so it includes negative nums
    integar = 1

# %%
# Fix 2: prevented incomplete outputs
  # original:

for num in range (1, integar + 1):
    if num % 3 == 0 and num % 5 == 0:
      output.append("FizzBuzz")
    elif num % 3 == 0:
      output.append("Fizz")
    elif num % 5 == 0:
      output.append("Buzz")
    else:
      output.append(str(num))
  return output


  # fixed
  # in this version, the return statement is placed so it is out of the for loop
  # which allows every number in the range to be interated through
  for num in range (1, integar + 1):
    if num % 3 == 0 and num % 5 == 0:
      output.append("FizzBuzz")
    elif num % 3 == 0:
      output.append("Fizz")
    elif num % 5 == 0:
      output.append("Buzz")
    else:
      output.append(str(num))
  return output

# %% [markdown]
# ## 5. Reflection on Your Contribution
# _Where did AI or Other's code helped or fail to help? What specific logic or debugging did you contribute yourself?_
#
# ## Example
# 1. I used ChatGPT (Level 4) to help identify an edge case where my draft code failed when the input string started with a closing bracket. I also used ChatGPT to help structure the final loop and mapping dictionary, but verified all logic myself by tracing the code.
#
# 2.  I used ChatGPT to help write the loop. But the code had an indentation error after the `if` block, which caused it to fail. I fixed the spacing and made sure the code runs correctly.
#
# 3. I used opensource code from Github. I found and fixed a logic bug where they used if s[i] == '(' or ')', which always returned True. I corrected it to properly check both conditions.

# %% [markdown]
# I used the solution code from LeekCode. The solution code provided me with the logic (using modulus) in order to complete the code, however the code they used, while short (one line) was overtly complicated and difficult for an outside perspective to understand, so i wrote my own longer but easily understandable code.

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# #  Problem 2

# %% [markdown]
# ## 1. Understanding & Breakdown
#
# _Understand the problem, inputs/outputs, constraints, and  write down your plan or steps to solve the problem or draw the flowchart using digital or real pen-paper. Insert the image._
#
# **AI Level 1** is allowed to understand the concept, but you need to sketch the problem down by yourself.
#
# **Your effort is more important than the accuracy for this section**

# %%
input integar
if integar is less than 0
  return false
else:
  string = string(integar)
  return string is equal to string[::-1]

# %% [markdown]
# ## 2. Peer Review & Draft Code
#
# **Review Guidance:**
# Visit the **"Solutions"** tab on LeetCode for the selected problem and review at least one top-rated solution. You may also search for relevant discussions or Q&A threads on **Stack Overflow** or other forums to understand how others approached the problem.
#
# Then, write your own version based on what you understood. The goal is not to copy but to apply what you learned. Always include links to the resources you reviewed.
#
# ---
#
# ### **Example Answer (for "Palindrome Number"):**
#
# I reviewed the top solution under the LeetCode “Solutions” tab and one post on Stack Overflow:
# https://stackoverflow.com/questions/17129222/how-to-check-if-a-number-is-palindrome-in-python
#
# I learned that I can reverse the integer using a loop with modulo and division instead of converting it to a string. Using this idea, I tried writing a function that reverses the number and compares it to the original.

# %%
# Your draft code here (does not need to be fully correct)
''' after reviewing this top solution under LeetCode:
https://leetcode.com/problems/palindrome-number/solutions/7196479/c-python-step-by-step-visuals-naive-optimal-beats-100-o-n-time-o-1-space/
I learned that instead of reversing the integar using a long line of arithmetic, i could just convert it to a string and reverse it with
pythons built in methods'''

def palindromenumber(integar: int) -> bool:
  if integar < 0:
    return False
  return str(integar) == str(integar)[::-1]

# %% [markdown]
# ## 3. Final Correct Code
#
# _This version must pass all required test cases and handle edge cases correctly._
#
# At this stage, you may:
# - Use reviewed solutions or programming AI tools (e.g., ChatGPT, GitHub Copilot) to refine and fix errors.
# - Refactor your draft to ensure accuracy and completeness.
#
#  **AI Level 4 is allowed**, but you **must include a disclaimer** that clearly states what tools you used, how you used them, and for which part of the code.

# %%
# Final working solution
# [AI Disclaimer example: Used ChatGPT with prompt “How to handle recursion base case” only for concept]
def palindrome_number(integar: int) -> bool:
  if integar < 0: #returns false as integars with a negative sign cant be palindromes
    return False
  return str(integar) == str(integar)[::-1]

# %% [markdown]
# Add the screenshot of output for all the test cases from your working solutions. ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 4. Review & Fixes
# _What did you improve from your draft? 2 fixes with your comments._

# %%
# Fix 1: renamed function to follow proper naming conventions
  #palindromenumber -> palindrome_number

# %%
# Fix 2: added comments that clear up the purpose of sections of the code

# %% [markdown]
# ## 5. Reflection on Your Contribution
# _Where did AI or Other's code helped or fail to help? What specific logic or debugging did you contribute yourself?_
#
# ## Example
# 1. I used ChatGPT (Level 4) to help identify an edge case where my draft code failed when the input string started with a closing bracket. I also used ChatGPT to help structure the final loop and mapping dictionary, but verified all logic myself by tracing the code.
#
# 2.  I used ChatGPT to help write the loop. But the code had an indentation error after the `if` block, which caused it to fail. I fixed the spacing and made sure the code runs correctly.
#
# 3. I used opensource code from Github. I found and fixed a logic bug where they used if s[i] == '(' or ')', which always returned True. I corrected it to properly check both conditions.

# %% [markdown]
# the opensource solutions from LeetCode offered insight onto how to complete the code, however the edits and code itself was mine

# %% [markdown]
# #  Problem 3

# %% [markdown]
# ## 1. Understanding & Breakdown
#
# _Understand the problem, inputs/outputs, constraints, and  write down your plan or steps to solve the problem or draw the flowchart using digital or real pen-paper. Insert the image._
#
# **AI Level 1** is allowed to understand the concept, but you need to sketch the problem down by yourself.
#
# **Your effort is more important than the accuracy for this section**

# %% [markdown]
# reverse integar asks us to create a python function that recieves an integar and returns the "reverse" integar (i.e 123 -> 321).
# some cases to watch for:
# *   negative inputs
# *   non integar input
# *   palindromes
#
# steps:
#
# 1.   convert int to str
# 2.   if negative, remove sign
# 3.   reverse the str
# 4.   convert back from str to int
# 5.   if the int was originally negative, multiply by -1
# 6.   return

# %% [markdown]
# ## 2. Peer Review & Draft Code
#
# **Review Guidance:**
# Visit the **"Solutions"** tab on LeetCode for the selected problem and review at least one top-rated solution. You may also search for relevant discussions or Q&A threads on **Stack Overflow** or other forums to understand how others approached the problem.
#
# Then, write your own version based on what you understood. The goal is not to copy but to apply what you learned. Always include links to the resources you reviewed.
#
# ---
#
# ### **Example Answer (for "Palindrome Number"):**
#
# I reviewed the top solution under the LeetCode “Solutions” tab and one post on Stack Overflow:
# https://stackoverflow.com/questions/17129222/how-to-check-if-a-number-is-palindrome-in-python
#
# I learned that I can reverse the integer using a loop with modulo and division instead of converting it to a string. Using this idea, I tried writing a function that reverses the number and compares it to the original.

# %%
# Your draft code here (does not need to be fully correct)
'''
peer review:
upon reviewing the top solution for reverse integar:
https://leetcode.com/problems/reverse-integer/solutions/5428589/video-using-remainder/
it acknowledged some test cases that i had not previously considered (negative inputs)
and i learnt how to deal with them
'''
def reverse_integar(n:int) -> int:
  if n < 0:
    neg = True
    n = n * -1

  if neg == True:
    return n[::-1] * -1
  else:
    return n[::-1]

# %% [markdown]
# ## 3. Final Correct Code
#
# _This version must pass all required test cases and handle edge cases correctly._
#
# At this stage, you may:
# - Use reviewed solutions or programming AI tools (e.g., ChatGPT, GitHub Copilot) to refine and fix errors.
# - Refactor your draft to ensure accuracy and completeness.
#
#  **AI Level 4 is allowed**, but you **must include a disclaimer** that clearly states what tools you used, how you used them, and for which part of the code.

# %%
# Final working solution
# [AI Disclaimer example: Used ChatGPT with prompt “How to handle recursion base case” only for concept]
def rev_int(integar: int) -> int:
  neg = False

  if integar < 0: # checks if int is negative
    neg = True
    integar = integar * -1 # removes the negative sign from less-than-zero inputs

  str_conv = str(integar)

  if neg == True:
    return int(str_conv[::-1]) * -1 # adds the negative sign back onto negative inputs
  else:
    return int(str_conv[::-1])
print(rev_int(-123))
print(rev_int(-20))
print(rev_int(20))
print(rev_int(133))
# Out:
# -321
# -2
# 2
# 331

# %% [markdown]
# Add the screenshot of output for all the test cases from your working solutions.![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 4. Review & Fixes
# _What did you improve from your draft? 2 fixes with your comments._

# %%
# Fix 1: added missing type conversions:
# original:
  if n < 0:
    neg = True
    n = n * -1

  if neg == True:
    return n[::-1] * -1
  else:
    return n[::-1]
# fixed:

  if integar < 0: # checks if int is negative
    neg = True
    integar = integar * -1 # removes the negative sign from less-than-zero inputs

  str_conv = str(integar)

  if neg == True:
    return int(str_conv[::-1]) * 1 # adds the negative sign back onto negative inputs
  else:
    return int(str_conv[::-1])

# %%
# Fix 2: added missing variable definition
# draft:
  if n < 0:
    neg = True
    n = n * -1
# final:
  neg = False

  if integar < 0: # checks if int is negative
    neg = True
    integar = integar * -1 # removes the negative sign from less-than-zero inputs

# %% [markdown]
# ## 5. Reflection on Your Contribution
# _Where did AI or Other's code helped or fail to help? What specific logic or debugging did you contribute yourself?_
#
# ## Example
# 1. I used ChatGPT (Level 4) to help identify an edge case where my draft code failed when the input string started with a closing bracket. I also used ChatGPT to help structure the final loop and mapping dictionary, but verified all logic myself by tracing the code.
#
# 2.  I used ChatGPT to help write the loop. But the code had an indentation error after the `if` block, which caused it to fail. I fixed the spacing and made sure the code runs correctly.
#
# 3. I used opensource code from Github. I found and fixed a logic bug where they used if s[i] == '(' or ')', which always returned True. I corrected it to properly check both conditions.

# %% [markdown]
# i used opensource solution code from LeetCode that influenced and inspired some of the logic in my code, however the final product was verified and corrected by myself, examining edge cases and specific instances where the code might have failed (negative inputs and such)

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# #  Problem 4

# %% [markdown]
# ## 1. Understanding & Breakdown
#
# _Understand the problem, inputs/outputs, constraints, and  write down your plan or steps to solve the problem or draw the flowchart using digital or real pen-paper. Insert the image._
#
# **AI Level 1** is allowed to understand the concept, but you need to sketch the problem down by yourself.
#
# **Your effort is more important than the accuracy for this section**

# %%
'''
recieve 2 inputs (list(int), int)
using the list of ints, find two values in the list that add to equal the desired int

logic: created a nested for loop that iterates through the indices of the list twice
so it compares every index in the loop to the rest of the indices
check the sum of both values at each index

# %% [markdown]
# ## 2. Peer Review & Draft Code
#
# **Review Guidance:**
# Visit the **"Solutions"** tab on LeetCode for the selected problem and review at least one top-rated solution. You may also search for relevant discussions or Q&A threads on **Stack Overflow** or other forums to understand how others approached the problem.
#
# Then, write your own version based on what you understood. The goal is not to copy but to apply what you learned. Always include links to the resources you reviewed.
#
# ---
#
# ### **Example Answer (for "Palindrome Number"):**
#
# I reviewed the top solution under the LeetCode “Solutions” tab and one post on Stack Overflow:
# https://stackoverflow.com/questions/17129222/how-to-check-if-a-number-is-palindrome-in-python
#
# I learned that I can reverse the integer using a loop with modulo and division instead of converting it to a string. Using this idea, I tried writing a function that reverses the number and compares it to the original.

# %% [markdown]
# i reviewed one of the top solutions on LeetCode, in this solution they presented the idea of using a nested for-loop to "brute" force their way, however in their method, the loop iterates through previously checked combinations, so i wrote it , using the nested forloop as inspiration, in a manner to decrease runtime/complexity

# %%
# Your draft code here (does not need to be fully correct)
def two_sum(lst:list, integar: int) -> list:
  for i1 in range(0, len(lst)):
    for i2 in range(i1 - 1, len(lst)):
      if lst[i1] + lst[i2] == integar:
        return [i1, i2]
      else:
        pass

# %% [markdown]
# ## 3. Final Correct Code
#
# _This version must pass all required test cases and handle edge cases correctly._
#
# At this stage, you may:
# - Use reviewed solutions or programming AI tools (e.g., ChatGPT, GitHub Copilot) to refine and fix errors.
# - Refactor your draft to ensure accuracy and completeness.
#
#  **AI Level 4 is allowed**, but you **must include a disclaimer** that clearly states what tools you used, how you used them, and for which part of the code.

# %%
# Final working solution
# [AI Disclaimer example: Used ChatGPT with prompt “How to handle recursion base case” only for concept]
def two_sum(lst: list, integar: int) -> list:

  for i1 in range(0, len(lst)):
    for i2 in range(i1 - 1, len(lst)): # iterates through unchecked values

      if lst[i1] + lst[i2] == integar: #checks the sum of values

        return [i1, i2] # returns list of correct values
  return [] #if every value of the list is iterated through and there is no output, return empty list
lst = []
for num in range(-10,10):
  lst.append(num)

# %% [markdown]
# Add the screenshot of output for all the test cases from your working solutions.
# ![Q4 test cases.png](data:image/png;base64,...)

# %% [markdown]
# ## 4. Review & Fixes
# _What did you improve from your draft? 2 fixes with your comments._

# %%
# Fix 1: dealt with case in which there was no solution:

#draft: had no return statement if there were no solutions

# final: returns empty list of no possible solution
 return []

# %%
# Fix 2: added white space and proper commenting

# %% [markdown]
# ## 5. Reflection on Your Contribution
# _Where did AI or Other's code helped or fail to help? What specific logic or debugging did you contribute yourself?_
#
# ## Example
# 1. I used ChatGPT (Level 4) to help identify an edge case where my draft code failed when the input string started with a closing bracket. I also used ChatGPT to help structure the final loop and mapping dictionary, but verified all logic myself by tracing the code.
#
# 2.  I used ChatGPT to help write the loop. But the code had an indentation error after the `if` block, which caused it to fail. I fixed the spacing and made sure the code runs correctly.
#
# 3. I used opensource code from Github. I found and fixed a logic bug where they used if s[i] == '(' or ')', which always returned True. I corrected it to properly check both conditions.

# %% [markdown]
# the code was written exclusively by me with inspiration from top solutions on LeetCode

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# #  Problem 5

# %% [markdown]
# ## 1. Understanding & Breakdown
#
# _Understand the problem, inputs/outputs, constraints, and  write down your plan or steps to solve the problem or draw the flowchart using digital or real pen-paper. Insert the image._
#
# **AI Level 1** is allowed to understand the concept, but you need to sketch the problem down by yourself.
#
# **Your effort is more important than the accuracy for this section**

# %%
'''

inputs:
string
outputs:
bool

first, remove non-alphanumeric values from the string and change to lowercase(we can use isalnum() & lower() methods)
then we can copy and reverse the string.
'''

# %% [markdown]
# ## 2. Peer Review & Draft Code
#
# **Review Guidance:**
# Visit the **"Solutions"** tab on LeetCode for the selected problem and review at least one top-rated solution. You may also search for relevant discussions or Q&A threads on **Stack Overflow** or other forums to understand how others approached the problem.
#
# Then, write your own version based on what you understood. The goal is not to copy but to apply what you learned. Always include links to the resources you reviewed.
#
# ---
#
# ### **Example Answer (for "Palindrome Number"):**
#
# I reviewed the top solution under the LeetCode “Solutions” tab and one post on Stack Overflow:
# https://stackoverflow.com/questions/17129222/how-to-check-if-a-number-is-palindrome-in-python
#
# I learned that I can reverse the integer using a loop with modulo and division instead of converting it to a string. Using this idea, I tried writing a function that reverses the number and compares it to the original.

# %%
# Your draft code here (does not need to be fully correct)

'''
# code review
#upon reviewing the top solutions on LeetCode, i learnt that i could use pythons built
#in methods .isalnum() and .lower() to easily convert/check the validity of every
#character in the string
'''
def valid_palindrome(input: str) -> bool:
  new_str = ''
  for char in input:
    if char.isalnum() == True:
      new_str += char.lower()
  return new_str == new_str[::-1]
# Out:
# True
# False
# True

# %% [markdown]
# ## 3. Final Correct Code
#
# _This version must pass all required test cases and handle edge cases correctly._
#
# At this stage, you may:
# - Use reviewed solutions or programming AI tools (e.g., ChatGPT, GitHub Copilot) to refine and fix errors.
# - Refactor your draft to ensure accuracy and completeness.
#
#  **AI Level 4 is allowed**, but you **must include a disclaimer** that clearly states what tools you used, how you used them, and for which part of the code.

# %%
# Final working solution
# [AI Disclaimer example: Used ChatGPT with prompt “How to handle recursion base case” only for concept]
def valid_palindrome(input: str) -> bool:

  new_str = ''

  for char in input: # iterates through every character

    if char.isalnum() == True: # checks if each char is alphanumeric (a-z, 0-9)
      new_str += char.lower() # if above is satisfied, a new string is constructed with the lowercase equiv of each char

  return new_str == new_str[::-1] # returns true or false if the palindrome is valid

# %% [markdown]
# Add the screenshot of output for all the test cases from your working solutions.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 4. Review & Fixes
# _What did you improve from your draft? 2 fixes with your comments._

# %%
# Fix 1: added white space and commenting

# %%
# Fix 2: changed variable names as to not confuse:

#draft: def valid_palindrome(string:str) -> bool:
  # the variable name along with the type int make it very confusing

#Final: def valid_palindrome(input: str) -> bool:

# %% [markdown]
# ## 5. Reflection on Your Contribution
# _Where did AI or Other's code helped or fail to help? What specific logic or debugging did you contribute yourself?_
#
# ## Example
# 1. I used ChatGPT (Level 4) to help identify an edge case where my draft code failed when the input string started with a closing bracket. I also used ChatGPT to help structure the final loop and mapping dictionary, but verified all logic myself by tracing the code.
#
# 2.  I used ChatGPT to help write the loop. But the code had an indentation error after the `if` block, which caused it to fail. I fixed the spacing and made sure the code runs correctly.
#
# 3. I used opensource code from Github. I found and fixed a logic bug where they used if s[i] == '(' or ')', which always returned True. I corrected it to properly check both conditions.

# %% [markdown]
# i used inspiration from LeetCode solutions to convert and check the validity of each character, the code was written by me

# %% [markdown]
# #  Repeat this template for Problems 2–5
# You may copy-paste the above section 4 more times or duplicate cells in your notebook environment.
#
# Remember:
# Proper attribution
# No copy-pasting from AI or others

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# 1. Your Name: Han Xu
# 2. Section:  001
# 3. ID: 20543486
# 4. Github Link of this notebook (the link of Github Repo where you saved your notebook)
# 5. Chat (Saved Chat  with your AI tool in a shared Document link)[Optional]

# %% [markdown]
# # **The most important part of writing code is not the code itself, but the thinking that leads to it. Thank You**
